# %%
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForCausalLM, DataCollatorForSeq2Seq, TrainingArguments, Trainer

# %%
ds = Dataset.load_from_disk("./alpaca_data_zh/")
ds
# Out:
# Dataset({
#     features: ['output', 'input', 'instruction'],
#     num_rows: 26858
# })

# %%
tokenizer = AutoTokenizer.from_pretrained("Langboat/bloom-1b4-zh")
tokenizer
# Out:
# BloomTokenizerFast(name_or_path='Langboat/bloom-1b4-zh', vocab_size=46145, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='left', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '<pad>'}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	0: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	3: AddedToken("<pad>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }
# )

# %%
def process_func(example):
    MAX_LENGTH = 256
    input_ids, attention_mask, labels = [], [], []
    instruction = tokenizer("\n".join(["Human: " + example["instruction"], example["input"]]).strip() + "\n\nAssistant: ")
    response = tokenizer(example["output"] + tokenizer.eos_token)
    input_ids = instruction["input_ids"] + response["input_ids"]
    attention_mask = instruction["attention_mask"] + response["attention_mask"]
    labels = [-100] * len(instruction["input_ids"]) + response["input_ids"]
    if len(input_ids) > MAX_LENGTH:
        input_ids = input_ids[:MAX_LENGTH]
        attention_mask = attention_mask[:MAX_LENGTH]
        labels = labels[:MAX_LENGTH]
    return {
        "input_ids": input_ids,
        "attention_mask": attention_mask,
        "labels": labels
    }

# %%
tokenized_ds = ds.map(process_func, remove_columns=ds.column_names)
tokenized_ds
# Out:
# Map:   0%|          | 0/26858 [00:00<?, ? examples/s]
# Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 26858
# })

# %%
model = AutoModelForCausalLM.from_pretrained("Langboat/bloom-1b4-zh")

# %% [markdown]
# # IA3配置

# %%
from peft import get_peft_model,IA3Config,TaskType

config = IA3Config(task_type=TaskType.CAUSAL_LM)
config
# Out:
# IA3Config(task_type=<TaskType.CAUSAL_LM: 'CAUSAL_LM'>, peft_type=<PeftType.IA3: 'IA3'>, auto_mapping=None, peft_version='0.18.0', base_model_name_or_path=None, revision=None, inference_mode=False, target_modules=None, exclude_modules=None, feedforward_modules=None, fan_in_fan_out=False, modules_to_save=None, init_ia3_weights=True)

# %%
model = get_peft_model(model,config)

# %%
model
# Out:
# PeftModelForCausalLM(
#   (base_model): IA3Model(
#     (model): BloomForCausalLM(
#       (transformer): BloomModel(
#         (word_embeddings): Embedding(46145, 2048)
#         (word_embeddings_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#         (h): ModuleList(
#           (0-23): 24 x BloomBlock(
#             (input_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (self_attention): BloomAttention(
#               (query_key_value): Linear(
#                 (base_layer): Linear(in_features=2048, out_features=6144, bias=True)
#                 (ia3_l): ParameterDict(  (default): Parameter containing: [torch.FloatTensor of size 6144x1])
#               )
#               (dense): Linear(in_features=2048, out_features=2048, bias=True)
#               (attention_dropout): Dropout(p=0.0, inplace=False)
#             )
#             (post_attention_layernorm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             (mlp): BloomMLP(
#               (dense_h_to_4h): Linear(in_features=2048, out_features=8192, bias=True)
#               (gelu_impl): BloomGelu()
#               (dense_4h_to_h): Linear(
#                 (base_layer): Linear(in_features=8192, out_features=2048, bias=True)
#                 (ia3_l): ParameterDict(  (default): Parameter containing: [torch.FloatTensor of size 1x8192])
#               )
#             )
#           )
#         )
#         (ln_f): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#       )
#       (lm_head): Linear(in_features=2048, out_features=46145, bias=False)
#     )
#   )
# )

# %%
config
# Out:
# IA3Config(task_type=<TaskType.CAUSAL_LM: 'CAUSAL_LM'>, peft_type=<PeftType.IA3: 'IA3'>, auto_mapping=None, peft_version='0.18.0', base_model_name_or_path='Langboat/bloom-1b4-zh', revision=None, inference_mode=False, target_modules={'mlp.dense_4h_to_h', 'query_key_value'}, exclude_modules=None, feedforward_modules={'mlp.dense_4h_to_h'}, fan_in_fan_out=False, modules_to_save=None, init_ia3_weights=True)

# %%
model.print_trainable_parameters()
# Out:
# trainable params: 344,064 || all params: 1,303,455,744 || trainable%: 0.0264

# %%
args = TrainingArguments(
    output_dir="./chatbot/ia3",
    per_device_train_batch_size=1,
    gradient_accumulation_steps=8,
    logging_steps=10,
    num_train_epochs=1,
    learning_rate=3e-3#这种微调建议学习率调高点
)

# %%
trainer = Trainer(
    model=model,
    args=args,
    tokenizer=tokenizer,
    train_dataset=tokenized_ds,
    data_collator=DataCollatorForSeq2Seq(tokenizer=tokenizer, padding=True),
)
# Out:
# /var/folders/vt/2rwrwr1j1hn9724wbbsr7jm80000gn/T/ipykernel_1871/1988846643.py:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
trainer.train()
# Out:
# /Users/liuzhen/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='147' max='3358' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 147/3358 15:22 < 5:40:22, 0.16 it/s, Epoch 0.04/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.650300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.562100</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.550900</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>2.459900</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>2.415700</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>2.430400</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>2.306200</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>2.389900</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>2.219700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>2.351100</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>2.385900</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>2.280000</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>2.328100</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>2.330500</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 trainer.train()
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/transformers/trainer.py:2325, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2323         hf_hub_utils.enable_progress_bars()
#    2324 else:
# -> 2325     return inner_training_loop(
#    2326         args=args,
#    2327         resume_from_checkpoint=resume_from_checkpoint,
#    2328         trial=trial,
#    2329         ignore_keys_for_eval=ignore_keys_for_eval,
#    2330     )
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/transformers/trainer.py:2674, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2667 context = (
#    2668     functools.partial(self.accelerator.no_sync, model=model)
#    2669     if i != len(batch_samples) - 1
#    2670     and self.accelerator.distributed_type != DistributedType.DEEPSPEED
#    2671     else contextlib.nullcontext
#    2672 )
#    2673 with context():
# -> 2674     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2676 if (
#    2677     args.logging_nan_inf_filter
#    2678     and not is_torch_xla_available()
#    2679     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2680 ):
#    2681     # if loss is nan or inf simply add the average of previous logged losses
#    2682     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/transformers/trainer.py:4020, in Trainer.training_step(self, model, inputs, num_items_in_batch)
#    4017     return loss_mb.reduce_mean().detach().to(self.args.device)
#    4019 with self.compute_loss_context_manager():
# -> 4020     loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#    4022 del inputs
#    4023 if (
#    4024     self.args.torch_empty_cache_steps is not None
#    4025     and self.state.global_step % self.args.torch_empty_cache_steps == 0
#    4026 ):
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/transformers/trainer.py:4110, in Trainer.compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#    4108         kwargs["num_items_in_batch"] = num_items_in_batch
#    4109     inputs = {**inputs, **kwargs}
# -> 4110 outputs = model(**inputs)
#    4111 # Save past state if it exists
#    4112 # TODO: this needs to be fixed and made cleaner later.
#    4113 if self.args.past_index >= 0:
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/peft/peft_model.py:1923, in PeftModelForCausalLM.forward(self, input_ids, attention_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict, task_ids, **kwargs)
#    1921     with self._enable_peft_forward_hooks(**kwargs):
#    1922         kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 1923         return self.base_model(
#    1924             input_ids=input_ids,
#    1925             attention_mask=attention_mask,
#    1926             inputs_embeds=inputs_embeds,
#    1927             labels=labels,
#    1928             output_attentions=output_attentions,
#    1929             output_hidden_states=output_hidden_states,
#    1930             return_dict=return_dict,
#    1931             **kwargs,
#    1932         )
#    1934 batch_size = _get_batch_size(input_ids, inputs_embeds)
#    1935 if attention_mask is not None:
#    1936     # concat prompt attention mask
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/peft/tuners/tuners_utils.py:308, in BaseTuner.forward(self, *args, **kwargs)
#     307 def forward(self, *args: Any, **kwargs: Any):
# --> 308     return self.model.forward(*args, **kwargs)
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/transformers/models/bloom/modeling_bloom.py:875, in BloomForCausalLM.forward(self, input_ids, past_key_values, attention_mask, head_mask, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, **deprecated_arguments)
#     871     raise ValueError(f"Got unexpected arguments: {deprecated_arguments}")
#     873 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 875 transformer_outputs = self.transformer(
#     876     input_ids,
#     877     past_key_values=past_key_values,
#     878     attention_mask=attention_mask,
#     879     head_mask=head_mask,
#     880     inputs_embeds=inputs_embeds,
#     881     use_cache=use_cache,
#     882     output_attentions=output_attentions,
#     883     output_hidden_states=output_hidden_states,
#     884     return_dict=return_dict,
#     885     cache_position=cache_position,
#     886 )
#     887 hidden_states = transformer_outputs[0]
#     889 lm_logits = self.lm_head(hidden_states)
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/transformers/models/bloom/modeling_bloom.py:581, in BloomModel.forward(self, input_ids, past_key_values, attention_mask, head_mask, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, **deprecated_arguments)
#     578 if output_hidden_states:
#     579     all_hidden_states = all_hidden_states + (hidden_states,)
# --> 581 outputs = block(
#     582     hidden_states,
#     583     layer_past=past_key_values,
#     584     attention_mask=causal_mask,
#     585     head_mask=head_mask[i],
#     586     use_cache=use_cache,
#     587     output_attentions=output_attentions,
#     588     alibi=alibi,
#     589     cache_position=cache_position,
#     590 )
#     592 hidden_states = outputs[0]
#     593 if output_attentions:
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/transformers/modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning_once(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/transformers/models/bloom/modeling_bloom.py:423, in BloomBlock.forward(self, hidden_states, alibi, attention_mask, layer_past, head_mask, use_cache, output_attentions, cache_position)
#     420     residual = attention_output
#     422 # MLP.
# --> 423 output = self.mlp(layernorm_output, residual)
#     425 return output, attn_weights
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/transformers/models/bloom/modeling_bloom.py:357, in BloomMLP.forward(self, hidden_states, residual)
#     352         intermediate_output = intermediate_output + F.linear(
#     353             hidden_states[:, :, int(i * slices) : int((i + 1) * slices)],
#     354             self.dense_4h_to_h.weight[:, int(i * slices) : int((i + 1) * slices)],
#     355         )
#     356 else:
# --> 357     intermediate_output = self.dense_4h_to_h(hidden_states)
#     359 output = dropout_add(intermediate_output, residual, self.hidden_dropout, self.training)
#     361 return output
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/peft/tuners/ia3/layer.py:178, in Linear.forward(self, x, *args, **kwargs)
#     175     # TODO: weight.dtype can be != self.ia3_l[self.active_adapters].dtype
#     176     # e.g. bf16 vs fp32. Is that okay?
#     177     interm = (x * ia3_scaling).to(previous_dtype)
# --> 178     result = self.base_layer(interm, *args, **kwargs)
#     179 else:
#     180     result = self.base_layer(x, *args, **kwargs)
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Documents/PEFT_Study/.venv/lib/python3.12/site-packages/torch/nn/modules/linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
import torch
device = "mps"
model = model.to(device)
ipt = tokenizer("Human: {}\n{}".format("考试有哪些技巧？", "").strip() + "\n\nAssistant: ", return_tensors="pt").to(model.device)
tokenizer.decode(model.generate(**ipt, max_length=128, do_sample=True)[0], skip_special_tokens=True)
# Out:
# 'Human: 考试有哪些技巧？\n\nAssistant: 考试技巧可分为两个层次：一是针对考试本身，考生需要了解大纲相关的信息，同时熟悉考试的各个章节，了解每道题目应该如何答对以及如何分配答题时间；二是针对考生的具体考试情况，即考试当天的情况。在考试当天，需要考生准备充足的知识储备，合理地分配答题时间，以保证能够正确答对所有的考试题目。'
